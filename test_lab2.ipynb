# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#ref_test_100Hz = '/Users/kamalizzuddin/Documents/Master/messung 20. august/raw220825/test5wtm_micros.csv'
ref_test_100Hz = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/1st_28Aug.csv'
ref_100Hz = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/28Aug_100Hz.csv'
ref_500Hz = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/28Aug_500Hz.csv'
ref_500Hz_8 = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/28Aug_500Hz2_8g.csv'
ref_500Hz_16 = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/28Aug_500Hz2_16g.csv'
ref_1300Hz = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/28Aug_1300Hz.csv'
ref_1300Hz_8 = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/28Aug_1300Hz2_8g.csv'
ref_1300Hz_16 = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/28Aug_1300Hz2_16g.csv'
ref_1300Hz_2 = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/28Aug_1300Hz3_2g.csv'
ref_50Hz = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/28Aug_50Hz.csv'
ref_Rd1 = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/28Aug_Rd1.csv'
ref_Rd2 = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/28Aug_Rd2.csv'

test_100Hz = '/Users/kamalizzuddin/Documents/Master/messung 20. august/raw220825/3rd.csv'

test500Hz = '/Users/kamalizzuddin/Documents/Master/messung4sept/lis3dh/500Hz_16g.csv'
test500Hz_7200 = '/Users/kamalizzuddin/Documents/Master/messung4sept/lis3dh/500Hz_16g_7200Fs.csv'
test1300Hz_7200 = '/Users/kamalizzuddin/Documents/Master/messung4sept/lis3dh/1300Hz_16g_7200Fs.csv'
test1300Hz = '/Users/kamalizzuddin/Documents/Master/messung4sept/lis3dh/1300Hz_16g_4650Fs.csv'

test50Hz_dfr = '/Users/kamalizzuddin/Documents/Master/messung4sept/icm42688/DFR_50Hz_16g.csv'
test100Hz_dfr= '/Users/kamalizzuddin/Documents/Master/messung4sept/icm42688/DFR_100Hz_16g.csv'
test500Hz_dfr = '/Users/kamalizzuddin/Documents/Master/messung4sept/icm42688/DFR_500Hz_16g.csv'
test1300Hz_dfr = '/Users/kamalizzuddin/Documents/Master/messung4sept/icm42688/DFR_1300Hz_16g.csv'
testrd_dfr = '/Users/kamalizzuddin/Documents/Master/messung4sept/icm42688/DFR_Rnd_16g.csv'



lab_50_psd = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/Sensor_28.08.2025/50Hz_PSD.txt'
lab_50_tp = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/Sensor_28.08.2025/50Hz_Time.txt'
lab_100_psd = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/Sensor_28.08.2025/100Hz_PSD.txt'
lab_100_tp = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/Sensor_28.08.2025/100Hz_Time.txt'
lab_500_psd = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/Sensor_28.08.2025/500Hz_PSD.txt'
lab_500_tp = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/Sensor_28.08.2025/500Hz_Time.txt'
lab_500_psd_8g = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/Sensor_28.08.2025/500Hz_PSD_8G.txt'
lab_500_tp_8g = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/Sensor_28.08.2025/500Hz_Time_8G.txt'
lab_500_psd_16g = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/Sensor_28.08.2025/500Hz_PSD_16G.txt'
lab_500_tp_16g = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/Sensor_28.08.2025/500Hz_Time_16G.txt'
lab_1300_psd_8g = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/Sensor_28.08.2025/1300Hz_PSD_8G.txt'
lab_1300_tp_8g = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/Sensor_28.08.2025/1300Hz_Time_8G.txt'
lab_1300_psd_16g = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/Sensor_28.08.2025/1300Hz_PSD_16G.txt'
lab_1300_tp_16g = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/Sensor_28.08.2025/1300Hz_Time_16G.txt'
lab_1300_psd_2g = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/Sensor_28.08.2025/1300Hz_PSD_2G.txt'
lab_1300_tp_2g = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/Sensor_28.08.2025/1300Hz_Time_2G.txt'
lab_1300_psd = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/Sensor_28.08.2025/1300Hz_PSD.txt'
lab_1300_tp = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/Sensor_28.08.2025/1300Hz_Time.txt'
lab_rd1_psd = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/Sensor_28.08.2025/50-1300Hz_PSD.txt'
lab_rd1_tp = '/Users/kamalizzuddin/Documents/Master/messung_28Aug/Sensor_28.08.2025/50-1300Hz_Time.txt'

lab_test1300Hz_tp= '/Users/kamalizzuddin/Documents/Master/messung4sept/lab/1300Hz_04.09.2025/Time_1300Hz_04.08.2025.txt'
lab_test500Hz_tp = '/Users/kamalizzuddin/Documents/Master/messung4sept/lab/500Hz_04.09.2025/Time_500Hz_04.08.2025.txt'

lab_test50Hz_tp_dfr= '/Users/kamalizzuddin/Documents/Master/messung4sept/DFR/50Hz_04.09.2025DFR/DFR_Time_50Hz_04.09.2025.txt'
lab_test100Hz_tp_dfr= '/Users/kamalizzuddin/Documents/Master/messung4sept/DFR/100Hz_04.09.2025DFR/DFR_Time_100Hz_04.09.2025.txt'
lab_test500Hz_tp_dfr= '/Users/kamalizzuddin/Documents/Master/messung4sept/DFR/500Hz_04.09.2025DFR/DFR_Time_500Hz_04.08.2025.txt'
lab_test1300Hz_tp_dfr = '/Users/kamalizzuddin/Documents/Master/messung4sept/DFR/1300Hz_04.09.2025DFR/DFR_Time_1300Hz_04.08.2025.txt'
lab_testrd_tp_dfr = '/Users/kamalizzuddin/Documents/Master/messung4sept/DFR/RND_50-1300Hz_04.09.2025DFR/DFR_Time_Rnd_04.09.2025.txt'

# %%
ref_messung50_psd = '/Users/kamalizzuddin/Documents/Master/messung 20. august/reference/Sin_50Hz/50Hz_1/PSD_50Hz_SensorResponse1.txt'
ref_messung50_psd_ref = '/Users/kamalizzuddin/Documents/Master/messung 20. august/reference/Sin_50Hz/50Hz_1/PSD_50Hz_SensorReference1.txt'
ref_messung50_tp = '/Users/kamalizzuddin/Documents/Master/messung 20. august/reference/Sin_50Hz/50Hz_1/Hh_Res_50Hz.txt'
ref_messung50_tp_ref = '/Users/kamalizzuddin/Documents/Master/messung 20. august/reference/Sin_50Hz/50Hz_1/Hh_Ref_50Hz.txt'

dfr_messung50_psd = '/Users/kamalizzuddin/Documents/Master/messung 20. august/reference/Sin_50Hz/50Hz_DFR/PSD_50Hz_SensorResponse_DFR.txt'
dfr_messung50_tp = '/Users/kamalizzuddin/Documents/Master/messung 20. august/reference/Sin_50Hz/50Hz_DFR/Th_DFR_Res_50Hz.txt'


#'/Users/kamalizzuddin/Documents/Master/messung 20. august/reference'
ref_messung100_psd = '/Users/kamalizzuddin/Documents/Master/messung 20. august/reference/Sin_100Hz/100Hz_1/PSD_100Hz_SensorResponse1.txt'
ref_messung100_psd_ref = '/Users/kamalizzuddin/Documents/Master/messung 20. august/reference/Sin_100Hz/100Hz_1/PSD_100Hz_SensorReference1.txt'
ref_messung100_tp = '/Users/kamalizzuddin/Documents/Master/messung 20. august/reference/Sin_100Hz/100Hz_1/Hh_Res_100Hz.txt'
ref_messung100_tp_ref = '/Users/kamalizzuddin/Documents/Master/messung 20. august/reference/Sin_100Hz/100Hz_1/Hh_Ref_100Hz.txt'
#
ref_messung500_psd = '/Users/kamalizzuddin/Documents/Master/messung 20. august/reference/Sin_500Hz/500Hz_1/PSD_500Hz_SensorResponse1.txt'
ref_messung500_psd_ref = '/Users/kamalizzuddin/Documents/Master/messung 20. august/reference/Sin_500Hz/500Hz_1/PSD_500Hz_SensorReference1.txt'
ref_messung500_tp = '/Users/kamalizzuddin/Documents/Master/messung 20. august/reference/Sin_500Hz/500Hz_1/Hh_Res_500Hz.txt'
ref_messung500_tp_ref = '/Users/kamalizzuddin/Documents/Master/messung 20. august/reference/Sin_500Hz/500Hz_1/Hh_Ref_500Hz.txt'
#
ref_messung1300_psd = '/Users/kamalizzuddin/Documents/Master/messung 20. august/reference/Sin_1300Hz/1300Hz_1/PSD_1300Hz_SensorResponse1.txt'
ref_messung1300_psd_ref = '/Users/kamalizzuddin/Documents/Master/messung 20. august/reference/Sin_1300Hz/1300Hz_1/PSD_1300Hz_SensorReference1.txt'
ref_messung1300_tp = '/Users/kamalizzuddin/Documents/Master/messung 20. august/reference/Sin_1300Hz/1300Hz_1/Hh_Res_1300Hz.txt'
ref_messung1300_tp_ref = '/Users/kamalizzuddin/Documents/Master/messung 20. august/reference/Sin_1300Hz/1300Hz_1/Hh_Ref_1300Hz.txt'

test_ref_100Hz = '/Users/kamalizzuddin/Documents/Master/messung 20. august/raw220825/22_08_2025-Hr.Izzuddin/3rd/TP.txt'
# ref_messung50_psd_dfr = '/Users/kamalizzuddin/Documents/Master/messung 20. august/reference/Sin_50Hz/50Hz_1/PSD_50Hz_SensorResponse_DFR.txt'
# ref_messung50_psd_dfr_ref = '/Users/kamalizzuddin/Documents/Master/messung 20. august/reference/Sin_50Hz/50Hz_1/PSD_50Hz_SensorReference_DFR.txt'
# ref_messung50_tp_dfr = '/Users/kamalizzuddin/Documents/Master/messung 20. august/reference/Sin_50Hz/50Hz_DFR/Th_DFR_Res_50Hz.txt'
# ref_messung50_tp_dfr_ref = '/Users/kamalizzuddin/Documents/Master/messung 20. august/reference/Sin_50Hz/50Hz_1/Th_DFR_Ref_50Hz.txt'
#
#
# ref_messung100_psd = '/Users/kamalizzuddin/Documents/Master/messung2 Juli/reference/Messung2_sin_100Hz/PSD.txt'
# ref_messung100_tp  = '/Users/kamalizzuddin/Documents/Master/messung2 Juli/reference/Messung2_sin_100Hz/TP.txt'
#
# ref_messung100_3_psd = '/Users/kamalizzuddin/Documents/Master/messung2 Juli/reference/Messung3_sin_100Hz/PSD.txt'
# ref_messung100_3_tp  = '/Users/kamalizzuddin/Documents/Master/messung2 Juli/reference/Messung3_sin_100Hz/TP.txt'
#
# ref_messung500_psd = '/Users/kamalizzuddin/Documents/Master/messung2 Juli/reference/Messung4_sin_500Hz/PSD.txt'
# ref_messung500_tp  = '/Users/kamalizzuddin/Documents/Master/messung2 Juli/reference/Messung4_sin_500Hz/TP.txt'
#
# # ref_messung500_dfr_old_psd = '/Users/kamalizzuddin/Documents/Master/messung2 Juli/reference/Messung5_DFR_sin_500Hz_old/PSD.txt'
# # ref_messung500_dfr_old_tp  = '/Users/kamalizzuddin/Documents/Master/messung2 Juli/reference/Messung5_DFR_sin_500Hz_old/TP.txt'
# ref_messung500_dfr_psd = '/Users/kamalizzuddin/Documents/Master/messung2 Juli/reference/Messung5_DFR_sin_500Hz/PSD.txt'
# ref_messung500_dfr_tp  = '/Users/kamalizzuddin/Documents/Master/messung2 Juli/reference/Messung5_DFR_sin_500Hz/TP.txt'
#
# ref_messung100_dfr_1_psd = '/Users/kamalizzuddin/Documents/Master/messung2 Juli/reference/Messung6_DFR_sin_100Hz/PSD.txt'
# ref_messung100_dfr_1_tp  = '/Users/kamalizzuddin/Documents/Master/messung2 Juli/reference/Messung6_DFR_sin_100Hz/TP.txt'
#
# ref_messung100_dfr_2_psd = '/Users/kamalizzuddin/Documents/Master/messung2 Juli/reference/Messung7_DFR_sin_100Hz/PSD.txt'
# ref_messung100_dfr_2_tp  = '/Users/kamalizzuddin/Documents/Master/messung2 Juli/reference/Messung7_DFR_sin_100Hz/TP.txt'

#
messung50 = '/Users/kamalizzuddin/Documents/Master/messung 20. august/Sin50Hz_LIS3DH.csv'
messung100 = '/Users/kamalizzuddin/Documents/Master/messung 20. august/Sin100Hz_LIS3DH.csv'
messung500 = '/Users/kamalizzuddin/Documents/Master/messung 20. august/Sin500Hz_LIS3DH.csv'
messung1300 = '/Users/kamalizzuddin/Documents/Master/messung 20. august/Sin1300Hz_LIS3DH.csv'
messungrn = '/Users/kamalizzuddin/Documents/Master/messung 20. august/Random_LIS3DH.csv'

messung50_dfr = '/Users/kamalizzuddin/Documents/Master/messung 20. august/Sin50Hz_ICM42688.csv'
messung100_dfr = '/Users/kamalizzuddin/Documents/Master/messung 20. august/Sin100Hz_ICM42688.csv'
messung500_dfr = '/Users/kamalizzuddin/Documents/Master/messung 20. august/Sin500Hz_ICM42688.csv'
messung1300_dfr = '/Users/kamalizzuddin/Documents/Master/messung 20. august/Sin1300Hz_ICM42688.csv'
messungrn_dfr = '/Users/kamalizzuddin/Documents/Master/messung 20. august/Random_ICM42688.csv'

# %%
td = pd.read_csv(ref_messung50_psd, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=43)
td_tp = pd.read_csv(ref_messung50_tp, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)

dfr_td = pd.read_csv(dfr_messung50_psd, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=43)
dfr_td_tp = pd.read_csv(dfr_messung50_tp, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)

td2 = pd.read_csv(ref_messung100_psd, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=43)
td2_tp = pd.read_csv(ref_messung100_tp, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)
#
td3 = pd.read_csv(ref_messung500_psd, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=43)
td3_tp = pd.read_csv(ref_messung500_tp, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)
#
td4 = pd.read_csv(ref_messung1300_psd, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=43)
td4_tp = pd.read_csv(ref_messung1300_tp, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)
#
tp_test_100 = pd.read_csv(test_ref_100Hz, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)
# # td5 = pd.read_csv(ref_messung500_dfr_old_psd, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=43)
# # td5_tp = pd.read_csv(ref_messung500_dfr_old_tp, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)
#
# td5 = pd.read_csv(ref_messung500_dfr_psd, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=43)
# td5_tp = pd.read_csv(ref_messung500_dfr_tp, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)
#
# td6 = pd.read_csv(ref_messung100_dfr_1_psd, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=43)
# td6_tp = pd.read_csv(ref_messung100_dfr_1_tp, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)
#
#
#
# td7 = pd.read_csv(ref_messung100_dfr_2_psd, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=43)
# td7_tp = pd.read_csv(ref_messung100_dfr_2_tp, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)

# %%
psd50 = pd.read_csv(lab_50_psd, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=44)
tp50 = pd.read_csv(lab_50_tp, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)

psd100 = pd.read_csv(lab_100_psd, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=44)
tp100 = pd.read_csv(lab_100_tp, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)

psd500 = pd.read_csv(lab_500_psd, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=44)
tp500 = pd.read_csv(lab_500_tp, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)

psd500_8g = pd.read_csv(lab_500_psd_8g, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=44)
tp500_8g = pd.read_csv(lab_500_tp_8g, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)

psd500_16g = pd.read_csv(lab_500_psd_16g, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=44)
tp500_16g = pd.read_csv(lab_500_tp_16g, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)

psd1300 = pd.read_csv(lab_1300_psd, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=44)
tp1300 = pd.read_csv(lab_1300_tp, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)

psd1300_2g = pd.read_csv(lab_1300_psd_2g, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=44)
tp1300_2g = pd.read_csv(lab_1300_tp_2g, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)

psd1300_8g = pd.read_csv(lab_1300_psd_8g, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=44)
tp1300_8g = pd.read_csv(lab_1300_tp_8g, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)

psd1300_16g = pd.read_csv(lab_1300_psd_16g, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=44)
tp1300_16g = pd.read_csv(lab_1300_tp_16g, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)

psd_rd = pd.read_csv(lab_rd1_psd, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=44)
tp_rd = pd.read_csv(lab_rd1_tp, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)

# psd_ = pd.read_csv(lab_rd1_psd, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=44)
tp_1300Hz = pd.read_csv(lab_test1300Hz_tp, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)
# psd_rd = pd.read_csv(lab_rd1_psd, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=44)
tp_500Hz = pd.read_csv(lab_test500Hz_tp, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)


# psd_ = pd.read_csv(lab_rd1_psd, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=44)
tp_50Hz_dfr = pd.read_csv(lab_test50Hz_tp_dfr, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)
# psd_rd = pd.read_csv(lab_rd1_psd, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=44)
tp_100Hz_dfr = pd.read_csv(lab_test100Hz_tp_dfr, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)
# psd_ = pd.read_csv(lab_rd1_psd, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=44)
tp_500Hz_dfr = pd.read_csv(lab_test500Hz_tp_dfr, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)
# psd_rd = pd.read_csv(lab_rd1_psd, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=44)
tp_1300Hz_dfr = pd.read_csv(lab_test1300Hz_tp_dfr, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)
# psd_ = pd.read_csv(lab_rd1_psd, header=None, names=['Hz', 'g^2/Hz', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=44)
tp_rd_dfr = pd.read_csv(lab_testrd_tp_dfr, header=None, names=['time', 'accel', 'c3', 'c4', 'c5'],encoding='ISO-8859-1', sep='\t', decimal='.', skiprows=34)

# %%
# sd = pd.read_csv(messung2_1, sep=';', decimal='.', names=['ind', 'time', 'x', 'y', 'z'], header=None)


sd = pd.read_csv(messung50, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None)
sd.columns = sd.iloc[0]
sd = sd[1:]

dfr_sd = pd.read_csv(messung100_dfr, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None)
dfr_sd.columns = dfr_sd.iloc[0]
dfr_sd = dfr_sd[1:]

sd2 = pd.read_csv(messung100, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None)
sd2.columns = sd2.iloc[0]
sd2 = sd2[1:]

sd3 = pd.read_csv(messung500, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None)
sd3.columns = sd3.iloc[0]
sd3 = sd3[1:]

sd4 = pd.read_csv(messung1300, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None)
sd4.columns = sd4.iloc[0]
sd4 = sd4[1:]

sd5 = pd.read_csv(messungrn, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None)
sd5.columns = sd5.iloc[0]
sd5 = sd5[1:]

# sd6 = pd.read_csv(messung500_dfr, sep=';', decimal='.',  names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None)
# sd6.columns = sd6.iloc[0]
# sd6 = sd6[1:]

sd7 = pd.read_csv(messungrn_dfr, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None)
sd7.columns = sd7.iloc[0]
sd7 = sd7[1:]

sd8 = pd.read_csv(messung50_dfr, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None)
sd8.columns = sd8.iloc[0]
sd8 = sd8[1:]

sd9 = pd.read_csv(messung100_dfr, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None)
sd9.columns = sd9.iloc[0]
sd9 = sd9[1:]

sd10 = pd.read_csv(messung500_dfr, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None)
sd10.columns = sd10.iloc[0]
sd10 = sd10[1:]

sd11 = pd.read_csv(messung1300_dfr, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None)
sd11.columns = sd11.iloc[0]
sd11 = sd11[1:]


sdtest = pd.read_csv(ref_test_100Hz, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None )
sdtest.columns = sdtest.iloc[0]
sdtest = sdtest[1:]

sdtest_50 = pd.read_csv(ref_50Hz, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None )
sdtest_50.columns = sdtest_50.iloc[0]
sdtest_50 = sdtest_50[1:]

sdtest100 = pd.read_csv(ref_100Hz, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None )
sdtest100.columns = sdtest100.iloc[0]
sdtest100 = sdtest100[1:]

sdtest500 = pd.read_csv(ref_500Hz, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None )
sdtest500.columns = sdtest500.iloc[0]
sdtest500 = sdtest500[1:]
sdtest500_8g = pd.read_csv(ref_500Hz_8, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None )
sdtest500_8g.columns = sdtest500_8g.iloc[0]
sdtest500_8g = sdtest500_8g[1:]
sdtest500_16g = pd.read_csv(ref_500Hz_16, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None )
sdtest500_16g.columns = sdtest500_16g.iloc[0]
sdtest500_16g = sdtest500_16g[1:]

sdtest1300 = pd.read_csv(ref_1300Hz, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None )
sdtest1300.columns = sdtest1300.iloc[0]
sdtest1300 = sdtest1300[1:]
sdtest1300_2g = pd.read_csv(ref_1300Hz_2, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None )
sdtest1300_2g.columns = sdtest1300_2g.iloc[0]
sdtest1300_2g = sdtest1300_2g[1:]
sdtest1300_8g = pd.read_csv(ref_1300Hz_8, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None )
sdtest1300_8g.columns = sdtest1300_8g.iloc[0]
sdtest1300_8g = sdtest1300_8g[1:]
sdtest1300_16g = pd.read_csv(ref_1300Hz_16, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None )
sdtest1300_16g.columns = sdtest1300_16g.iloc[0]
sdtest1300_16g = sdtest1300_16g[1:]

sdtest5 = pd.read_csv(ref_Rd1, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None )
sdtest5.columns = sdtest5.iloc[0]
sdtest5 = sdtest5[1:]

sdtest6 = pd.read_csv(ref_Rd2, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None )
sdtest6.columns = sdtest6.iloc[0]
sdtest6 = sdtest6[1:]

sdtest2_500 = pd.read_csv(test500Hz, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None )
sdtest2_500.columns = sdtest2_500.iloc[0]
sdtest2_500 = sdtest2_500[1:]

sdtest2_500_7200 = pd.read_csv(test500Hz_7200, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None )
sdtest2_500_7200.columns = sdtest2_500_7200.iloc[0]
sdtest2_500_7200 = sdtest2_500_7200[1:]

sdtest2_1300 = pd.read_csv(test1300Hz, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None )
sdtest2_1300.columns = sdtest2_1300.iloc[0]
sdtest2_1300 = sdtest2_1300[1:]

sdtest2_1300_7200 = pd.read_csv(test1300Hz_7200, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None )
sdtest2_1300_7200.columns = sdtest2_1300_7200.iloc[0]
sdtest2_1300_7200 = sdtest2_1300_7200[1:]


sdtest3_50_dfr = pd.read_csv(test50Hz_dfr, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None )
sdtest3_50_dfr.columns = sdtest3_50_dfr.iloc[0]
sdtest3_50_dfr = sdtest3_50_dfr[1:]

sdtest3_100_dfr = pd.read_csv(test100Hz_dfr, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None )
sdtest3_100_dfr.columns = sdtest3_100_dfr.iloc[0]
sdtest3_100_dfr = sdtest3_100_dfr[1:]

sdtest3_500_dfr = pd.read_csv(test500Hz_dfr, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None )
sdtest3_500_dfr.columns = sdtest3_500_dfr.iloc[0]
sdtest3_500_dfr = sdtest3_500_dfr[1:]

sdtest3_1300_dfr = pd.read_csv(test1300Hz_dfr, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None )
sdtest3_1300_dfr.columns = sdtest3_1300_dfr.iloc[0]
sdtest3_1300_dfr = sdtest3_1300_dfr[1:]

sdtest3_rd_dfr = pd.read_csv(testrd_dfr, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None )
sdtest3_rd_dfr.columns = sdtest3_rd_dfr.iloc[0]
sdtest3_rd_dfr = sdtest3_rd_dfr[1:]
# Out:
# /var/folders/bq/ctbgtv5x1yd30jm7495gvrmh0000gn/T/ipykernel_49377/3053247817.py:4: DtypeWarning: Columns (0,1,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   sd = pd.read_csv(messung50, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None)
# /var/folders/bq/ctbgtv5x1yd30jm7495gvrmh0000gn/T/ipykernel_49377/3053247817.py:57: DtypeWarning: Columns (0,1,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   sdtest_50 = pd.read_csv(ref_50Hz, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None )
# /var/folders/bq/ctbgtv5x1yd30jm7495gvrmh0000gn/T/ipykernel_49377/3053247817.py:61: DtypeWarning: Columns (0,1,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   sdtest100 = pd.read_csv(ref_100Hz, sep=';', decimal='.', names=['ind', 'time', 'AccX', 'AccY', 'AccZ'], header=None )
# ...

# %%
AccZ1 = sd['AccZ'].astype(float) -1.0
AccY1 = sd['AccY'].astype(float)
AccX1 = sd['AccX'].astype(float)

# timeTest = ( np.arange(len(sdTest['AccZ'])) * 1/5376) 
time1 = sd['t'].astype(float) / 1000000
newtime1 = ( np.arange(len(sd['AccZ'])) * 1/7200)


AccZ2 = sd2['AccZ'].astype(float) -1.0
# timeTest = ( np.arange(len(sdTest['AccZ'])) * 1/5376) 
time2 = sd2['t'].astype(float) / 1000000
AccX2 = sd2['AccX'].astype(float)

AccZ2dfr = dfr_sd['AccZ'].astype(float) /1000 - 1.0
# timeTest = ( np.arange(len(sdTest['AccZ'])) * 1/5376)
time2dfr = (np.arange(len(dfr_sd['AccZ'])) * 1/4273)
AccX2dfr = dfr_sd['AccX'].astype(float) / 1000


AccZ3 = sd3['AccZ'].astype(float) -1.0
# timeTest = ( np.arange(len(sdTest['AccZ'])) * 1/5376) 
time3 = sd3['t'].astype(float) / 1000000
AccX3 = sd3['AccX'].astype(float)


AccZ4 = sd4['AccZ'].astype(float) -1.0
# timeTest = ( np.arange(len(sdTest['AccZ'])) * 1/5376) 
time4 = sd4['t'].astype(float) / 1000000
AccX4 = sd4['AccX'].astype(float)


AccZ5 = sd5['AccZ'].astype(float) / 1000 - 1.00
# timeTest = ( np.arange(len(sdTest['AccZ'])) * 1/5376) 
# time5 = sd5['t'].astype(float) / 1000000
time5 = sd5['t'].astype(float) / 1000000

# AccZ6 = sd6['AccZ'].astype(float) / 1000 - 1.00
# # timeTest = ( np.arange(len(sdTest['AccZ'])) * 1/5376)
# # time6 = sd6['t'].astype(float) / 1000000
# time6 = (np.arange(len(sd6['AccZ'])) * 1/4273)


AccZ7 = sd7['AccZ'].astype(float) / 1000 - 1.00
# timeTest = ( np.arange(len(sdTest['AccZ'])) * 1/5376) 
# time7 = sd7['t'].astype(float) / 1000000
time7 = (np.arange(len(sd7['AccZ'])) * 1/4273)


AccZTest = sdtest['AccZ'].astype(float) - 1.00
AccXTest = sdtest['AccX'].astype(float)
AccYTest = sdtest['AccY'].astype(float)

# timeTest = ( np.arange(len(sdTest['AccZ'])) * 1/5376)
# time7 = sd7['t'].astype(float) / 1000000
timeTest = sdtest['t'].astype(float) / 1000000
newTimeTest = (np.arange(len(sdtest['AccZ'])) * 1/7200)


AccZTest50 = sdtest_50['AccZ'].astype(float) - 1.00
AccXTest50 = sdtest_50['AccX'].astype(float)
AccYTest50 = sdtest_50['AccY'].astype(float)
timeTest50 = sdtest_50['t'].astype(float) / 1000000
newTimeTest50 = (np.arange(len(sdtest_50['AccY'])) * 1/7200)

AccZTest100 = sdtest100['AccZ'].astype(float) - 1.00
AccXTest100 = sdtest100['AccX'].astype(float)
AccYTest100 = sdtest100['AccY'].astype(float)
timeTest100 = sdtest100['t'].astype(float) / 1000000
newTimeTest100 = (np.arange(len(sdtest100['AccY'])) * 1/7200)

AccZTest500 = sdtest500['AccZ'].astype(float) - 1.00
AccXTest500 = sdtest500['AccX'].astype(float)
AccYTest500 = sdtest500['AccY'].astype(float)
timeTest500 = sdtest500['t'].astype(float) / 1000000
newTimeTest500 = (np.arange(len(sdtest500['AccY'])) * 1/7200)


AccZTest500_8 = sdtest500_8g['AccZ'].astype(float) - 1.00
AccXTest500_8 = sdtest500_8g['AccX'].astype(float)
AccYTest500_8 = sdtest500_8g['AccY'].astype(float)
timeTest500_8 = sdtest500_8g['t'].astype(float) / 1000000
newTimeTest500_8 = (np.arange(len(sdtest500_8g['AccY'])) * 1/7200)

AccZTest500_16 = sdtest500_16g['AccZ'].astype(float) - 1.00
AccXTest500_16 = sdtest500_16g['AccX'].astype(float)
AccYTest500_16 = sdtest500_16g['AccY'].astype(float)
timeTest500_16 = sdtest500_16g['t'].astype(float) / 1000000
newTimeTest500_16 = (np.arange(len(sdtest500_16g['AccY'])) * 1/7200)

AccZTest1300 = sdtest1300['AccZ'].astype(float) - 1.00
AccXTest1300 = sdtest1300['AccX'].astype(float)
AccYTest1300 = sdtest1300['AccY'].astype(float)
timeTest1300 = sdtest1300['t'].astype(float) / 1000000
newTimeTest1300 = (np.arange(len(sdtest1300['AccY'])) * 1/7200)

AccZTest1300_2 = sdtest1300_2g['AccZ'].astype(float) - 1.00
AccXTest1300_2 = sdtest1300_2g['AccX'].astype(float)
AccYTest1300_2 = sdtest1300_2g['AccY'].astype(float)
timeTest1300_2 = sdtest1300_2g['t'].astype(float) / 1000000
newTimeTest1300_2 = (np.arange(len(sdtest1300_2g['AccY'])) * 1/7200)

AccZTest1300_8 = sdtest1300_8g['AccZ'].astype(float) - 1.00
AccXTest1300_8 = sdtest1300_8g['AccX'].astype(float)
AccYTest1300_8 = sdtest1300_8g['AccY'].astype(float)
timeTest1300_8 = sdtest1300_8g['t'].astype(float) / 1000000
newTimeTest1300_8 = (np.arange(len(sdtest1300_8g['AccY'])) * 1/7200)

AccZTest1300_16 = sdtest1300_16g['AccZ'].astype(float) - 1.00
AccXTest1300_16 = sdtest1300_16g['AccX'].astype(float)
AccYTest1300_16 = sdtest1300_16g['AccY'].astype(float)
timeTest1300_16 = sdtest1300_16g['t'].astype(float) / 1000000
newTimeTest1300_16 = (np.arange(len(sdtest1300_16g['AccY'])) * 1/7200)

AccZTestRd1 = sdtest5['AccZ'].astype(float) - 1.00
AccXTestRd1 = sdtest5['AccX'].astype(float)
AccYTestRd1 = sdtest5['AccY'].astype(float)
timeTestRd1 = sdtest5['t'].astype(float) / 1000000
newTimeTestRd1 = (np.arange(len(sdtest5['AccY'])) * 1/7200)

AccZTestRd2 = sdtest6['AccZ'].astype(float) - 1.00
AccXTestRd2 = sdtest6['AccX'].astype(float)
AccYTestRd2 = sdtest6['AccY'].astype(float)
timeTestRd2 = sdtest6['t'].astype(float) / 1000000
newTimeTestRd2 = (np.arange(len(sdtest6['AccY'])) * 1/7200)

AccZTest2_500 = sdtest2_500['AccZ'].astype(float) - 1.00
AccXTest2_500 = sdtest2_500['AccX'].astype(float)
AccYTest2_500 = sdtest2_500['AccY'].astype(float)
timeTest2_500 = sdtest2_500['t'].astype(float) / 1000000
newTimeTest2_500 = (np.arange(len(sdtest2_500['AccY'])) * 1/4650)

AccZTest2_500_7200 = sdtest2_500_7200['AccZ'].astype(float) - 1.00
AccXTest2_500_7200 = sdtest2_500_7200['AccX'].astype(float)
AccYTest2_500_7200 = sdtest2_500_7200['AccY'].astype(float)
timeTest2_500_7200 = sdtest2_500_7200['t'].astype(float) / 1000000
newTimeTest2_500_7200 = (np.arange(len(sdtest2_500_7200['AccY'])) * 1/7200)

AccZTest2_1300 = sdtest2_1300['AccZ'].astype(float) - 1.00
AccXTest2_1300 = sdtest2_1300['AccX'].astype(float)
AccYTest2_1300 = sdtest2_1300['AccY'].astype(float)
timeTest2_1300 = sdtest2_1300['t'].astype(float) / 1000000
newTimeTest2_1300 = (np.arange(len(sdtest2_1300['AccY'])) * 1/4650)

AccZTest2_1300_7200 = sdtest2_1300_7200['AccZ'].astype(float) - 1.00
AccXTest2_1300_7200 = sdtest2_1300_7200['AccX'].astype(float)
AccYTest2_1300_7200 = sdtest2_1300_7200['AccY'].astype(float)
timeTest2_1300_7200 = sdtest2_1300_7200['t'].astype(float) / 1000000
newTimeTest2_1300_7200 = (np.arange(len(sdtest2_1300_7200['AccY'])) * 1/7200)

AccZTest3_50_dfr = sdtest3_50_dfr['AccZ'].astype(float)/1000 - 1.00
AccXTest3_50_dfr = sdtest3_50_dfr['AccX'].astype(float)/1000
AccYTest3_50_dfr = sdtest3_50_dfr['AccY'].astype(float)/1000
timeTest3_50_dfr = sdtest3_50_dfr['t'].astype(float) / 1000000
timeTest3_50_dfr = timeTest3_50_dfr - timeTest3_50_dfr[0]
newTimeTest3_50_dfr = (np.arange(len(sdtest3_50_dfr['AccY'])) * 1/4650)
AccZTest3_100_dfr = sdtest3_100_dfr['AccZ'].astype(float)/1000  - 1.00
AccXTest3_100_dfr = sdtest3_100_dfr['AccX'].astype(float)/1000
AccYTest3_100_dfr= sdtest3_100_dfr['AccY'].astype(float)/1000
timeTest3_100_dfr = sdtest3_100_dfr['t'].astype(float) / 1000000
timeTest3_100_dfr = timeTest3_100_dfr - timeTest3_100_dfr[0]
newTimeTest3_100_dfr = (np.arange(len(sdtest3_100_dfr['AccY'])) * 1/4650)
AccZTest3_500_dfr = sdtest3_500_dfr['AccZ'].astype(float)/1000  - 1.00
AccXTest3_500_dfr = sdtest3_500_dfr['AccX'].astype(float)/1000
AccYTest3_500_dfr = sdtest3_500_dfr['AccY'].astype(float)/1000
timeTest3_500_dfr = sdtest3_500_dfr['t'].astype(float) / 1000000
timeTest3_500_dfr = timeTest3_500_dfr - timeTest3_500_dfr[0]
newTimeTest3_500_dfr = (np.arange(len(sdtest3_500_dfr['AccY'])) * 1/4650)
AccZTest3_1300_dfr = sdtest3_1300_dfr['AccZ'].astype(float)/1000  - 1.00
AccXTest3_1300_dfr = sdtest3_1300_dfr['AccX'].astype(float)/1000
AccYTest3_1300_dfr = sdtest3_1300_dfr['AccY'].astype(float)/1000
timeTest3_1300_dfr = sdtest3_1300_dfr['t'].astype(float) / 1000000
timeTest3_1300_dfr = timeTest3_1300_dfr - timeTest3_1300_dfr[0]
newTimeTest3_1300_dfr = (np.arange(len(sdtest3_1300_dfr['AccY'])) * 1/2731.3131118314)

AccZTest3_rd_dfr = sdtest3_rd_dfr['AccZ'].astype(float)/1000  - 1.00
AccXTest3_rd_dfr = sdtest3_rd_dfr['AccX'].astype(float)/1000
AccYTest3_rd_dfr = sdtest3_rd_dfr['AccY'].astype(float)/1000
timeTest3_rd_dfr = sdtest3_rd_dfr['t'].astype(float) / 1000000
timeTest3_rd_dfr = timeTest3_rd_dfr - timeTest3_rd_dfr[0]
newTimeTest3_rd_dfr = (np.arange(len(sdtest3_rd_dfr['AccY'])) * 1/4650)



# accelerationData = [
#     {'nr': 2 ,'freq': '50Hz','ref': {'time':td2_tp['time'], 'accel':td2_tp['accel'], 'type': "Reference", 'fsam': 1600}, 'sen': {'time': time2, 'accel': AccZ2, 'type': 'LIS3DH', 'fsam': 5376}},
#     {'nr': 3 ,'freq': '100Hz','ref': {'time':td3_tp['time'], 'accel':td3_tp['accel'], 'type': "Reference", 'fsam': 1600}, 'sen': {'time': time3, 'accel': AccZ3, 'type': 'LIS3DH', 'fsam': 5376}},
#     {'nr': 4 ,'freq': '500Hz','ref': {'time':td4_tp['time'], 'accel':td4_tp['accel'], 'type': "Reference", 'fsam': 4096}, 'sen': {'time': time4, 'accel': AccZ4, 'type': 'LIS3DH', 'fsam': 5376}},
#     {'nr': 5 ,'freq': '500Hz','ref': {'time':td5_tp['time'], 'accel':td5_tp['accel'], 'type': "Reference", 'fsam': 4096}, 'sen': {'time': time5, 'accel': AccZ5, 'type': 'ICM42688', 'fsam': 4273}},
#     #{'nr': 6 ,'freq': '100Hz','ref': {'time':td6_tp['time'], 'accel':td6_tp['accel'], 'type': "Reference", 'fsam': 1600}, 'sen': {'time': time6, 'accel': AccZ6, 'type': 'ICM42688', 'fsam': 4273}},
#     {'nr': 7 ,'freq': '100Hz','ref': {'time':td7_tp['time'], 'accel':td7_tp['accel'], 'type': "Reference", 'fsam': 1600}, 'sen': {'time': time7, 'accel': AccZ7, 'type': 'ICM42688', 'fsam': 4273}}
#     ]

# time4[48384:91392]-9;  [48384:91392] * 2.36
# psdData = [
#     {'nr': 2 ,'ref': {'time':td2_tp['time'], 'accel':td2_tp['accel']}, 'sen': {'time': time2, 'accel': AccZ2}}, 
#     {'nr': 3 ,'ref': {'time':td3_tp['time'], 'accel':td3_tp['accel']}, 'sen': {'time': time3, 'accel': AccZ3}}, 
#     {'nr': 4 ,'ref': {'time':td4_tp['time'], 'accel':td4_tp['accel']}, 'sen': {'time': time4, 'accel': AccZ4}}, 
#     {'nr': 5 ,'ref': {'time':td5_tp['time'], 'accel':td5_tp['accel']}, 'sen': {'time': time5, 'accel': AccZ5}}, 
#     {'nr': 6 ,'ref': {'time':td6_tp['time'], 'accel':td6_tp['accel']}, 'sen': {'time': time6, 'accel': AccZ6}}, 
#     {'nr': 7 ,'ref': {'time':td7_tp['time'], 'accel':td7_tp['accel']}, 'sen': {'time': time7, 'accel': AccZ7}}
#     ]
# Out:
# /var/folders/bq/ctbgtv5x1yd30jm7495gvrmh0000gn/T/ipykernel_49377/3041702294.py:155: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   timeTest3_50_dfr = timeTest3_50_dfr - timeTest3_50_dfr[0]
# /var/folders/bq/ctbgtv5x1yd30jm7495gvrmh0000gn/T/ipykernel_49377/3041702294.py:161: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   timeTest3_100_dfr = timeTest3_100_dfr - timeTest3_100_dfr[0]
# ...

# %%
timeTest500

# %%
import plotly.graph_objects as go
fig = go.Figure()


#fig.add_trace(go.Scatter(x=time1[244624:271506]-45.5, y=AccX1[244624:271506], name = 'LIS3DH ', mode='lines', line=dict(color='green', width=2)))
# fig.add_trace(go.Scatter(x=time4[43011:69893]-8, y=AccX4[43011:69893], name = 'LIS3DH ', mode='lines', line=dict(color='green', width=2)))
# fig.add_trace(go.Scatter(x=newTimeTest1300_16, y=AccYTest1300_16, name = 'LIS3DH 100 Hz ', mode='lines', line=dict(color='green', width=2)))
# fig.add_trace(go.Scatter(x=newTimeTest1300_2, y=AccYTest1300_2, name = 'LIS3DH 100 Hz ', mode='lines', line=dict(color='blue', width=2)))
# fig.add_trace(go.Scatter(x=tp1300_16g['time'], y=tp1300_16g['accel'], name = 'Lab 100 Hz ', mode='lines', line=dict(color='red', width=2)))

#50 Hz
#fig.add_trace(go.Scatter(x=timeTest50[1:] - 9.493049 - 7 + 0.0081219 + 0.0002441, y=AccYTest50[1:], name = 'LIS3DH 50 Hz ', mode='lines+markers', line=dict(color='blue', width=2)))
#fig.add_trace(go.Scatter(x=tp50['time'], y=tp50['accel'], name = 'Lab 50 Hz ', mode='lines+markers', line=dict(color='red', width=2)))

# 100 Hz
# fig.add_trace(go.Scatter(x=timeTest100[1:] - 11.025051 - 7.25 - 0.0022866, y=AccYTest100[1:], name = 'LIS3DH 500 Hz - 8g ', mode='lines+markers', line=dict(color='blue', width=2)))
# fig.add_trace(go.Scatter(x=tp100['time'], y=tp100['accel'], name = 'Lab 500 Hz ', mode='lines', line=dict(color='red', width=2)))

#500 Hz
#fig.add_trace(go.Scatter(x=timeTest50[1:] - 9.493049 - 7 + 0.0081219 + 0.0002441, y=AccYTest50[1:], name = 'LIS3DH 50 Hz ', mode='lines+markers', line=dict(color='blue', width=2)))
#fig.add_trace(go.Scatter(x=tp50['time'], y=tp50['accel'], name = 'Lab 50 Hz ', mode='lines+markers', line=dict(color='red', width=2)))


#fig.add_trace(go.Scatter(x=timeTest500[1:], y=AccYTest500[1:], name = 'Test ', mode='lines', line=dict(color='blue', width=2)))
#fig.add_trace(go.Scatter(x=timeTest500_8[1:], y=AccYTest500_8[1:], name = 'Test 8g ', mode='lines', line=dict(color='brown', width=2)))
#fig.add_trace(go.Scatter(x=timeTest500_16[1:]-13.5 -0.000129, y=AccYTest500_16[1:], name = 'Test 16g ', mode='lines+markers', line=dict(color='black', width=2)))
#fig.add_trace(go.Scatter(x=tp500['time'], y=tp500['accel'], name = 'Ref ', mode='lines', line=dict(color='purple', width=2)))
#fig.add_trace(go.Scatter(x=tp500_8g['time'], y=tp500_8g['accel'], name = 'Ref (8g)', mode='lines', line=dict(color='grey', width=2)))
#fig.add_trace(go.Scatter(x=tp500_16g['time'], y=tp500_16g['accel'], name = 'Ref (16) ', mode='lines+markers', line=dict(color='orange', width=2)))


# fig.add_trace(go.Scatter(x=timeTest1300[1:], y=AccYTest1300[1:], name = 'Test ', mode='lines', line=dict(color='blue', width=2)))
# fig.add_trace(go.Scatter(x=timeTest1300_2[1:], y=AccYTest1300_2[1:], name = 'Test 2g ', mode='lines', line=dict(color='brown', width=2)))
# fig.add_trace(go.Scatter(x=timeTest1300_8[1:], y=AccYTest1300_8[1:], name = 'Test 8g ', mode='lines', line=dict(color='black', width=2)))
# fig.add_trace(go.Scatter(x=timeTest1300_16[1:], y=AccYTest1300_16[1:], name = 'Test 16g ', mode='lines', line=dict(color='green', width=2)))
# fig.add_trace(go.Scatter(x=tp1300['time'], y=tp1300['accel'], name = 'Ref ', mode='lines', line=dict(color='purple', width=2)))
# fig.add_trace(go.Scatter(x=tp1300_2g['time'], y=tp1300_2g['accel'], name = 'Ref 2g', mode='lines', line=dict(color='grey', width=2)))
# fig.add_trace(go.Scatter(x=tp1300_8g['time'], y=tp1300_8g['accel'], name = 'Ref 8g ', mode='lines', line=dict(color='orange', width=2)))
# fig.add_trace(go.Scatter(x=tp1300_16g['time'], y=tp1300_16g['accel'], name = 'Ref 16g ', mode='lines', line=dict(color='pink', width=2)))


#fig.add_trace(go.Scatter(x=timeTest2_500 - 10 -0.000542, y=AccYTest2_500, name = 'Test 500 4650Hz ', mode='lines', line=dict(color='blue', width=2)))
#fig.add_trace(go.Scatter(x=timeTest2_500_7200 - 12 -0.000797, y=AccYTest2_500_7200, name = 'Test 500 7200Hz ', mode='lines', line=dict(color='grey', width=2)))
#fig.add_trace(go.Scatter(x=tp_500Hz['time'], y=tp_500Hz['accel'], name = 'Lab 500', mode='lines', line=dict(color='brown', width=2)))
#fig.add_trace(go.Scatter(x=timeTest2_1300, y=AccYTest2_1300, name = 'Test 1300 4650Hz ', mode='lines', line=dict(color='red', width=2)))
#fig.add_trace(go.Scatter(x=timeTest2_1300_7200, y=AccYTest2_1300_7200, name = 'Test 1300 7200Hz', mode='lines', line=dict(color='green', width=2)))
#fig.add_trace(go.Scatter(x=tp_1300Hz['time'], y=tp_1300Hz['accel'], name = 'Lab 1300', mode='lines', line=dict(color='purple', width=2)))

#fig.add_trace(go.Scatter(x=timeTest3_50_dfr, y=AccYTest3_50_dfr, name = 'Test 50 ', mode='lines', line=dict(color='red', width=2)))
#fig.add_trace(go.Scatter(x=timeTest3_100_dfr, y=AccYTest3_100_dfr, name = 'Test 100  ', mode='lines', line=dict(color='green', width=2)))
fig.add_trace(go.Scatter(x=timeTest3_500_dfr, y=AccYTest3_500_dfr, name = 'Test 500 ', mode='lines', line=dict(color='blue', width=2)))
fig.add_trace(go.Scatter(x=tp_1300Hz_dfr['time'], y=tp_1300Hz_dfr['accel'], name = 'Ref 500 ', mode='lines', line=dict(color='red', width=2)))
#fig.add_trace(go.Scatter(x=newTimeTest3_1300_dfr, y=AccYTest3_1300_dfr, name = 'Test 1300 ', mode='lines', line=dict(color='grey', width=2)))
#fig.add_trace(go.Scatter(x=timeTest3_rd_dfr, y=AccYTest3_rd_dfr, name = 'Test Random  ', mode='lines', line=dict(color='brown', width=2)))
#fig.add_trace(go.Scatter(x=tp_1300Hz_dfr['time']+7.5-0.00016 + 0.000274, y=tp_1300Hz_dfr['accel'], name = 'Lab 1300  ', mode='lines', line=dict(color='pink', width=2)))

#tp_1300Hz_dfr

#fig.add_trace(go.Scatter(x=time2dfr, y=AccX2dfr, name = 'DFR ', mode='lines', line=dict(color='black', width=2)))
#fig.update_xaxes(range=[8.705, 8.755])


fig.update_layout(
            title=dict(
                text='LIS3DH '
            ),
            xaxis=dict(
                title=dict(
                    text='Zeit [s]'
                )
            ),
            yaxis=dict(
                title=dict(
                    text='Acceleration [g]'
                )
            ),
    )


fig.show()

# for data in accelerationData:
#
#     fig = go.Figure()
#
#
#     fig.add_trace(go.Scatter(x=data['sen']['time'], y=data['sen']['accel'], name = data['sen']['type'], mode='lines',
#                             line=dict(color='green', width=2)))
#
#     fig.add_trace(go.Scatter(x=data['ref']['time'], y=data['ref']['accel'], name = data['ref']['type'], mode='lines',
#                              line=dict(color='red', width=2)))
#
#
#
#     fig.update_layout(
#             title=dict(
#                 text=f"{data['nr']} Gemessene Daten {data['sen']['type']} vs {data['ref']['type']} bei {data['freq']}"
#             ),
#             xaxis=dict(
#                 title=dict(
#                     text='Zeit [s]'
#                 )
#             ),
#             yaxis=dict(
#                 title=dict(
#                     text='Acceleration [g]'
#                 )
#             ),
#     )
#
#
#     fig.show()

# %%
fig_test = plt.figure(figsize=(13, 9), dpi=136)
ax1_test = fig_test.add_subplot(111)


#1st
# 50 Hz time = timeTest50[1:] - 9.493049 - 7 + 0.0081219 + 0.0002441 // 8192 Hz
# 100 Hz time = timeTest100[1:] - 11.025051 - 7.25 - 0.0022866  // 800 Hz
# 500 Hz = timeTest500_16[1:]-13.5 -0.000129 // 8192 Hz = 1.4-1.41

#2nd DFR
# 1300Hz = tp_1300Hz_dfr['time']+7.5-0.00016 + 0.000274 // 8192
measuredAccel = AccYTest3_1300_dfr
measuredTime = newTimeTest3_1300_dfr

mean1 = round(np.mean(measuredAccel), 5)
rms1 = round(np.sqrt(np.mean(measuredAccel**2)) , 2)
peak1 = round(np.max(np.abs(measuredAccel)) , 2)
ax1_test.plot(measuredTime , measuredAccel,label=f'Sensor 1300Hz \nFs: 2731 Hz; mean: {mean1}; \nrms: {rms1}; peak: {peak1}', marker='o', linestyle='dashed', color='black')

referenceAccel = tp_1300Hz_dfr['accel']
referenceTime = tp_1300Hz_dfr['time']+7.5-0.00016 + 0.000274
mean2 = round(np.mean(referenceAccel), 5)
rms2 = round(np.sqrt(np.mean(referenceAccel**2)) , 2)
peak2 = round(np.max(np.abs(referenceAccel)) , 2)
ax1_test.plot(referenceTime, referenceAccel, label=f'Ref.Sensor 1300Hz \nFs: 8192 Hz; mean: {mean2}; \nrms: {rms2}; peak: {peak2}', marker='o', linestyle='dashed', color='red')



line_test, label_test = ax1_test.get_legend_handles_labels()
ax1_test.legend(line_test, label_test, loc='upper center', bbox_to_anchor=(0.5,-0.055),fancybox=True, shadow=True, ncol=6)
ax1_test.minorticks_on()
ax1_test.set_xlabel('Zeit [s]')
# ax1.set_ylim(yrange)
ax1_test.set_ylabel('Acceleration [g]')
ax1_test.grid(True)

folder = "1300Hz"


ax1_test.set_title(f'Gemessene Daten Referenz vs LIS3DH bei {folder} (Skala 0,005)')

#ax1_test.set_xlim(8.71, 8.715)


plt.show()

#plt.savefig(f'download/4sept/{folder}_acc_0,005.png')

# %%
''
accFreq = AccYTest3_1300_dfr

#accelRef = td4_tp['accel']
#refDataPSD = td4
n = len(accFreq)

fhat = np.fft.fft(np.array(accFreq)) # FFT transform 
# fhat = fhat[:n // 2]
# dt = 0.000186
dt = 1/2731
# dt = 1/4273

# freq = np.fft.fftfreq(n, dt)[:n // 2]
freq = np.fft.fftfreq(n, dt)


PSD = (np.abs(fhat)**2)/ ((1/dt)* n)



L = np.arange(1, np.floor(n/2), dtype = 'int') # indices

# %%
psd1300_2g['Hz']

# %%
fig, axis = plt.subplots(1,1, figsize=(16, 8))



# plt.sca(axis[1])
plt.plot(freq[L], PSD[L], color = '#010A0C', linewidth = 2,
    label = 'Sensor 500 Hz')
# plt.plot(freq2[L2], PSD2[L2], color = '#0CBECD', linewidth = 2,
#     label = 'Sensor 20')
#plt.plot(psd100['Hz'], psd100['g^2/Hz'], color = '#0CBECD', linewidth = 2, label = 'Reference 500 Hz')
# plt.plot(freq2[L2], PSD2[L2], color = '#010A0C', linewidth = 2,
#     label = 'Derived Ref 100')
# plt.plot(freq3[L3], PSD3[L3], color = '#010A0C', linewidth = 2,
#     label = 'Sensor Check')


#plt.xlim(0, 130)
#
#plt.ylim(0, 0.001)
plt.grid()
plt.minorticks_on()
plt.legend()


plt.show()

# %%
from scipy.signal import welch

fig, axis = plt.subplots(1,1, figsize=(16, 8))


accFreq = AccYTest100
accelRef = tp100['accel']
refDataPSD = psd100
n = len(accFreq)

mean1 = round(np.mean(accelRef), 5)
rms1 = round(np.sqrt(np.mean(accelRef**2)) , 2)
peak1 = round(np.max(np.abs(accelRef)) , 2)

avg1 = 5
npsg1 = len(accelRef)/avg1
fsAccelRef = 800
ff_welch, Pxxx_welch = welch(accelRef, fs=fsAccelRef, nperseg=npsg1, scaling='density', window='hann')


peak_idx = np.argmax(Pxxx_welch)
df1 = ff_welch[peak_idx]
peak_value1 = Pxxx_welch[peak_idx]

half_max1 = peak_value1 / 2.0
above_half1 = np.where(Pxxx_welch >= half_max1)[0]

bw1_start = ff_welch[above_half1[0]]
bw1_end = ff_welch[above_half1[-1]]
bw1 = bw1_end - bw1_start
rmssq1 = round(np.trapezoid(Pxxx_welch, ff_welch), 2)



mean2 = round(np.mean(accFreq), 5)
rms2 = round(np.sqrt(np.mean(accFreq**2)) , 2)
peak2= round(np.max(np.abs(accFreq)) , 2)
avg2 = 14.35
fsSensor = 7200
# fsSensor = 4273

npsg2 = len(accFreq)/avg2
f2_welch, Pxx2_welch = welch(accFreq, fs=fsSensor, nperseg=npsg2, scaling='density', window='hann')

peak_idx2 = np.argmax(Pxx2_welch)
df2 = f2_welch[peak_idx2]
peak_value2 = Pxx2_welch[peak_idx2]

half_max2 = peak_value2 / 2.0
above_half2 = np.where(Pxx2_welch >= half_max2)[0]

bw2_start = f2_welch[above_half2[0]]
bw2_end = f2_welch[above_half2[-1]]
bw2 = bw2_end - bw2_start
# df2 = round(2)
# bw2 = round (2)
rmssq2 = round(np.trapezoid(Pxx2_welch, f2_welch), 2)
axis.plot(refDataPSD['Hz'], refDataPSD['g^2/Hz'], label=f'Reference - Fs: {fsAccelRef} Hz (Peak: {round(peak_value1,2)} g²/Hz)\nRMS²: {rmssq1} g²; Resolution: {avg1} Hz (nperseg: {npsg1}); \nDominant Freq: {round(df1, 4)}; Bandwidth: {round(bw1, 4)} Hz \n(mean: {mean1}; rms: {rms1}; peak: {peak1})')

axis.plot(f2_welch, Pxx2_welch, label=f'LIS3DH - Fs: {fsSensor} Hz (Peak: {round(peak_value2,2)} g²/Hz)\nRMS²: {rmssq2} g²; Resolution: {avg2} Hz (nperseg: {round(npsg2, 4)}); \nDominant Freq: {round(df2, 4)}; Bandwidth: {round(bw2, 4)} Hz \n(mean: {mean2}; rms: {rms2}; peak: {peak2})')

axis.set_xlabel("Frequency [Hz]")
axis.set_ylabel("PSD [g²/Hz]")
line_test, label_test = axis.get_legend_handles_labels()

axis.legend(line_test, label_test, loc='upper center', bbox_to_anchor=(0.5,-0.055),fancybox=True, shadow=True, ncol=6)



# plt.xlim(0, 1000)
plt.xlim(0, 300)

#plt.ylim(0, 10)
axis.grid(True)
# plt.legend()
plt.minorticks_on()
#plt.savefig("generated/mess2_LIS3DH/PSD_100Hz_small")


plt.show()

# %%
pd.Series(Pxxx_welch)

# %%
# fig, axis = plt.subplots(1,1, figsize=(16, 8))

# plt.legend()


# plt.sca(axis[1])
# plt.plot(freq[L], PSD[L], color = '#010A0C', linewidth = 2, 
#     label = 'ICM42688')
# plt.plot(td4['Hz'], td4['g^2/Hz'], color='red', linewidth = 2, 
#     label = 'Referenz')



# plt.xlim(300, 600)
# plt.xlim(0, 1)
plt.grid()
plt.legend()
plt.minorticks_on()

plt.show()

# %%
n
