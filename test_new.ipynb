# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import src.vibration.DataAcceleration as DataAcc

first = DataAcc.AccelerationData('/Users/kamalizzuddin/Documents/Master/messung2 Juli/sensor/file10.csv')
